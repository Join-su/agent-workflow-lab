# %% [markdown]
# # week2 03 — LangGraph workflow
#
# StateGraph의 node, edge, conditional edge와 실행 뒤 State를 확인합니다.

# %%
from week2.app import WORKFLOW

state = WORKFLOW.invoke({'amount': 120000, 'receipt_attached': False, 'purpose': 'client_meeting', 'agents_run': []})
state
