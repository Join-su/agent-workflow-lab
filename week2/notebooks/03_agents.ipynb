# %% [markdown]
# # Week 2 / 멀티 에이전트 (난이도 2)
#
# Retriever → Policy Reviewer → Risk Router로 증빙 부족을 `clarify`로 보냅니다.

# %% [markdown]
# ## 실습 순서
# 1. 아래 코드를 실행한다.
# 2. 출력의 `status`, `citations`, `agents_run`을 확인한다.
# 3. 질문 또는 입력을 바꾸고 테스트가 깨지지 않는지 확인한다.

# %%
from week2.app import ExpenseRequest, retrieve_policy, policy_reviewer, risk_router

payload = ExpenseRequest(amount=120000, receipt_attached=False, purpose="client_meeting")
review = policy_reviewer(payload, retrieve_policy(payload))
risk_router(review)
