# %% [markdown]
# # Week 2 / 배포 검증 (난이도 2)
#
# Week 2 API를 포트 8012에서 실행하고 receipt 누락 routing을 smoke test합니다.

# %% [markdown]
# ## 실습 순서
# 1. 아래 코드를 실행한다.
# 2. 출력의 `status`, `citations`, `agents_run`을 확인한다.
# 3. 질문 또는 입력을 바꾸고 테스트가 깨지지 않는지 확인한다.

# %%
import urllib.request

# .venv/bin/uvicorn week2.app:app --port 8012
# urllib.request.urlopen("http://127.0.0.1:8012/health").read().decode()
