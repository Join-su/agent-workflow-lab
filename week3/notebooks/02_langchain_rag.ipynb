# %% [markdown]
# # week3 02 — LangChain RAG
#
# LangChain Document, text splitter, Runnable 기반 retrieval 결과와 citation metadata를 확인합니다.

# %%
from week3.app import POLICY_CHUNKS, policy_retrieval_chain

print(POLICY_CHUNKS)
policy_retrieval_chain.invoke('정책 근거를 찾아주세요')
