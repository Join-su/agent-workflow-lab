# %% [markdown]
# # Week 3 / RAG (난이도 3)
#
# 보안 정책 evidence가 planner와 human review packet에 연결되는 구조를 확인합니다.

# %% [markdown]
# ## 실습 순서
# 1. 아래 코드를 실행한다.
# 2. 출력의 `status`, `citations`, `agents_run`을 확인한다.
# 3. 질문 또는 입력을 바꾸고 테스트가 깨지지 않는지 확인한다.

# %%
from week3.app import SECURITY_POLICY

SECURITY_POLICY
