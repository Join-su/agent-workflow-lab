# %% [markdown]
# # week1 03 — LangGraph workflow
#
# StateGraph의 node, edge, conditional edge와 실행 뒤 State를 확인합니다.

# %%
from week1.app import WORKFLOW

state = WORKFLOW.invoke({'question': '휴가 신청은 며칠 전에 해야 하나요?', 'agents_run': []})
state
