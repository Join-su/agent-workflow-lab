# %% [markdown]
# # week1 04 — Agent 평가·안전 경계
#
# 지원 질문은 answered+citation, 비지원 질문은 insufficient_evidence인지 확인한다. 실제 외부 Tool·권한 변경·업무 데이터는 사용하지 않습니다.

# %%
from week1.app import create_app
from fastapi.testclient import TestClient

client = TestClient(create_app())
client.post('/query', json={"question": "휴가 신청은 며칠 전에 해야 하나요?"}).json()
