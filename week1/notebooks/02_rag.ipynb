# %% [markdown]
# # Week 1 / RAG (난이도 1)
#
# 키워드 기반 fixture retrieval과 citation contract를 관찰합니다.

# %% [markdown]
# ## 실습 순서
# 1. 아래 코드를 실행한다.
# 2. 출력의 `status`, `citations`, `agents_run`을 확인한다.
# 3. 질문 또는 입력을 바꾸고 테스트가 깨지지 않는지 확인한다.

# %%
from week1.app import retrieve, answer

question = "휴가 신청은 며칠 전에 해야 하나요?"
evidence = retrieve(question)
print(evidence)
answer(question, evidence)
