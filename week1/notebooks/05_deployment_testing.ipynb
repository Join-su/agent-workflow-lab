# %% [markdown]
# # week1 05 — 배포 artifact·회귀 테스트
#
# Compose artifact와 자동 테스트의 역할을 구분합니다. 현재 환경에서는 Compose runtime이 미검증 상태입니다.

# %%
# 저장소 루트에서 실행:
# uv sync
# .venv/bin/python -m unittest discover -s . -p 'test_*.py' -v
# docker compose -f weekN/deploy/compose.yaml up --build  # 별도 Compose 환경에서만
