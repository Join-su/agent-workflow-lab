# %% [markdown]
# # week1 02 — LangChain RAG
#
# LangChain Document, text splitter, Runnable 기반 retrieval 결과와 citation metadata를 확인합니다.

# %%
from week1.app import POLICY_CHUNKS, retrieval_chain

print(POLICY_CHUNKS)
retrieval_chain.invoke('정책 근거를 찾아주세요')
