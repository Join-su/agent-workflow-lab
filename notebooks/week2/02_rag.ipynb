# %% [markdown]
# # Week 2 / RAG (난이도 2)
#
# 비용 정산 policy evidence를 조회하고 citation을 응답에 연결합니다.

# %% [markdown]
# ## 실습 순서
# 1. 아래 코드를 실행한다.
# 2. 출력의 `status`, `citations`, `agents_run`을 확인한다.
# 3. 질문 또는 입력을 바꾸고 테스트가 깨지지 않는지 확인한다.

# %%
from labs.week2_expense_review import ExpenseRequest, retrieve_policy

payload = ExpenseRequest(amount=120000, receipt_attached=False, purpose="client_meeting")
retrieve_policy(payload)
