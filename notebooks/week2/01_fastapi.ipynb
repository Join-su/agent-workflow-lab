# %% [markdown]
# # Week 2 / FastAPI (난이도 2)
#
# 출장비 증빙 검토 API의 요청 schema와 response를 확인합니다.

# %% [markdown]
# ## 실습 순서
# 1. 아래 코드를 실행한다.
# 2. 출력의 `status`, `citations`, `agents_run`을 확인한다.
# 3. 질문 또는 입력을 바꾸고 테스트가 깨지지 않는지 확인한다.

# %%
from fastapi.testclient import TestClient
from labs.week2_expense_review import create_app

client = TestClient(create_app())
client.post("/review", json={"amount":120000,"receipt_attached":False,"purpose":"client_meeting"}).json()
