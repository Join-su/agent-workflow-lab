# %% [markdown]
# # Week 1 / 배포 검증 (난이도 1)
#
# 로컬 서버 또는 Docker Compose 기동 뒤 health endpoint를 확인합니다.

# %% [markdown]
# ## 실습 순서
# 1. 아래 코드를 실행한다.
# 2. 출력의 `status`, `citations`, `agents_run`을 확인한다.
# 3. 질문 또는 입력을 바꾸고 테스트가 깨지지 않는지 확인한다.

# %%
import urllib.request

# 서버를 별도 터미널에서 먼저 실행합니다:
# .venv/bin/uvicorn labs.week1_policy_qa:app --port 8011
# urllib.request.urlopen("http://127.0.0.1:8011/health").read().decode()
